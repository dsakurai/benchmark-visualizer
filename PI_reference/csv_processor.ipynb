# %%
import pandas as pd

# %%
df = pd.read_csv(
    "data/pop100_50000iter/exp_csvs/GDE3_breadth_base_1_2_StoppingByEvaluations_2023-03-22T10-51-26.821709.csv",
    index_col=0,
)

# %%
df.head()
# Out:
#           t        x1        x2        y1        y2  eval_node_id  \
# 0  2.073404 -0.232205  0.328886  1.155762 -1.776474             0
# 1  1.766819  0.703809  0.084238  1.099457 -1.399203             0
# 2  2.833565 -0.339819  0.013106  1.302918 -2.704348             2
# 3  0.012519  0.426870  0.730514  0.008852 -0.008852             0
# 4  1.544486 -0.078853 -0.399846  0.723501 -1.460733             0
#
#   diagonal_length  step     t_org     y_org
# 0       [-1.  1.]     0  2.073404 -0.438909
# 1         [1. 1.]     1  1.766819 -0.211952
# 2     [0.25 0.25]     2  2.833565 -0.990961
# 3               0     3  0.012519  0.000000
# 4       [-1. -1.]     4  1.544486 -0.521301

# %%
sub_df = df.iloc[100:200]

# %%
sub_df[["t", "x1", "x2"]].values
# Out:
# array([[ 2.84937597,  0.53774883,  0.32888581],
#        [ 1.76681944, -0.16936459, -1.        ],
#        [ 2.01868986,  0.73299369,  0.68851352],
#        [ 0.3800528 ,  0.94313975, -0.62474201],
#        [ 0.40331975, -0.5359568 ,  0.10505886],
#        [ 0.73713069,  0.18940485, -0.68617554],
#        [ 2.87164656,  0.52704748,  0.30001619],
#        [ 1.62218232, -0.7092489 ,  0.67891258],
#        [ 0.01      ,  0.17784955,  1.        ],
#        [ 1.04965858,  0.39203575,  0.97883797],
#        [ 0.01442446,  0.20529752,  1.        ],
#        [ 1.10660084, -0.60887976, -0.23508655],
#        [ 2.32311787,  0.23332812,  1.        ],
#        [ 3.        ,  1.        , -0.15661462],
#        [ 0.01      ,  0.65809976, -0.33245523],
#        [ 0.25521996, -1.        , -0.7788562 ],
#        [ 1.73036043, -0.00577696, -1.        ],
#        [ 1.2017518 , -0.79298936,  0.91626007],
#        [ 0.01      , -0.89449756, -0.66589035],
#        [ 1.93918997,  0.69994242, -0.59365511],
# ...

# %%
dim = 100

variables_header = [f"x{x+1}" for x in range(dim - 1)]

# %%
variables_header.insert(0, "t")

# %%
variables_header
# Out:
# ['t',
#  'x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14',
#  'x15',
#  'x16',
#  'x17',
#  'x18',
#  'x19',
#  'x20',
#  'x21',
#  'x22',
#  'x23',
#  'x24',
#  'x25',
#  'x26',
#  'x27',
#  'x28',
#  'x29',
#  'x30',
#  'x31',
#  'x32',
#  'x33',
#  'x34',
#  'x35',
#  'x36',
#  'x37',
#  'x38',
#  'x39',
#  'x40',
#  'x41',
#  'x42',
#  'x43',
#  'x44',
#  'x45',
#  'x46',
#  'x47',
#  'x48',
#  'x49',
#  'x50',
#  'x51',
#  'x52',
#  'x53',
#  'x54',
#  'x55',
#  'x56',
#  'x57',
#  'x58',
#  'x59',
#  'x60',
#  'x61',
#  'x62',
#  'x63',
#  'x64',
#  'x65',
#  'x66',
#  'x67',
#  'x68',
#  'x69',
#  'x70',
#  'x71',
#  'x72',
#  'x73',
#  'x74',
#  'x75',
#  'x76',
#  'x77',
#  'x78',
#  'x79',
#  'x80',
#  'x81',
#  'x82',
#  'x83',
#  'x84',
#  'x85',
#  'x86',
#  'x87',
#  'x88',
#  'x89',
#  'x90',
#  'x91',
#  'x92',
#  'x93',
#  'x94',
#  'x95',
#  'x96',
#  'x97',
#  'x98',
#  'x99']
