# %%
from utils.local_pareto import get_local_pareto_set
import pandas as pd

# %%
dim_space = 3
tree_name = "breadth_base_1"
population_size = 100
total_generations = 5
variables_header = [f"x{x+1}" for x in range(dim_space - 1)]
variables_header.insert(0, "t")

# %%
pareto_dict = get_local_pareto_set(dimension=3, tree_name=tree_name)
data_path = "data/pop100_50000iter/exp_csvs/GDE3_breadth_base_1_3_StoppingByEvaluations_2023-03-22T10-51-27.031047.csv"
experiment_record = pd.read_csv(data_path, index_col=0)

# %%
generation = 49
starting_point = generation * population_size
generation_df = experiment_record.iloc[
    starting_point : starting_point + population_size
]
generation_points = generation_df[variables_header].values

# IGD computing function
# igd_result = IGD(reference = pareto_dict[node_id]["pareto_set"], computed_values =  generation_points)

# %%
generation_points[:100]

# %%
generation_points

# %%
pareto_dict[0]["pareto_front"]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 4.03119728e-18, -4.28549564e-02,  3.03030303e-02,
#         -3.03030303e-02],
#        [ 8.06239455e-18, -8.57099129e-02,  6.06060606e-02,
#         -6.06060606e-02],
#        [ 1.20935918e-17, -1.28564869e-01,  9.09090909e-02,
#         -9.09090909e-02],
#        [ 1.61247891e-17, -1.71419826e-01,  1.21212121e-01,
#         -1.21212121e-01],
#        [ 2.01559864e-17, -2.14274782e-01,  1.51515152e-01,
#         -1.51515152e-01],
#        [ 2.41871837e-17, -2.57129739e-01,  1.81818182e-01,
#         -1.81818182e-01],
#        [ 1.43405931e-17, -2.99984695e-01,  2.12121212e-01,
#         -2.12121212e-01],
#        [ 3.22495782e-17, -3.42839651e-01,  2.42424242e-01,
#         -2.42424242e-01],
#        [ 4.20291434e-17, -3.85694608e-01,  2.72727273e-01,
#         -2.72727273e-01],
#        [ 4.03119728e-17, -4.28549564e-01,  3.03030303e-01,
#         -3.03030303e-01],
# ...
